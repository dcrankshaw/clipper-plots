# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import json
import zipfile
# %matplotlib inline

# %%
def softmax(x):
    expx = np.exp(x - x.max())
    Z = expx.sum(1)
    a = expx / Z[:, np.newaxis]
    return a

# %%
X = np.zeros((10000,50))
data_path = "./data/clipper-cifar"
for i in range(5):
    feature = np.load(open(data_path + '/cifar_prob_features'+str(i+1)+'.npz.zip', 'r'))['arr_0']
    X[:,(i*10):(i+1)*10] = softmax(feature)
y = np.load(open(data_path + '/targets.npz.zip', 'r'))['arr_0'].astype('int32')
yhot = np.zeros((len(y), int(y.max()) +1))
yhot[np.arange(len(y)), y[:,0]] = 1

# %%
train_prop = 0.8
ind = np.random.permutation(len(X))
#ind = range(len(X))
train_ind = ind[:int(len(X) * train_prop)]
test_ind = ind[int(len(X) * train_prop):]

X_train = X[train_ind,:]
y_train = yhot[train_ind,:]

X_test = X[test_ind, :]
y_test = yhot[test_ind,:]
print X_test.shape, y_test.shape
# Out:
# (2000, 50) (2000, 10)

# %% [markdown]
# **original accuracy**

# %%
original_acc=[]
for i in range(5):
    acc = np.sum(np.argmax(X_test[:,i*10:(i+1)*10], axis=1) == np.argmax(y_test, axis=1))/float(y_test.shape[0])
    print i, ' accuracy = ', acc
    original_acc.append(acc)
# Out:
# 0  accuracy =  0.7575
# 1  accuracy =  0.654
# 2  accuracy =  0.832
# 3  accuracy =  0.54
# 4  accuracy =  0.9085

# %%
np.savez(open('split_data.npz','w'), x_train=X_train, x_test=X_test, y_train=y_train, y_test=y_test)

# %% [markdown]
# **weight averaging**

# %%
def eval_predictions(w):
    cnt = 0
    for i in range(X_test.shape[0]):
        res = np.zeros((10,))
        for j in range(5):
            res += w[j]*X_test[i,j*10:(j+1)*10]
        predicted = np.argmax(res)
        if np.argmax(y_test[i]) == predicted:
            cnt += 1
    return cnt/float(X_test.shape[0])

# %%
w = np.ones((5,))*0.2
w[0] = 0.2
w[1] = 0.1
w[2] = 0.3
w[3] = 0.1
w[4] = 0.4
acc = []
for i in range(200):
    cnt = 0
    res = np.zeros((10,))
    for j in range(5):
        res += w[j]*X_train[i,j*10:(j+1)*10]
    predicted = np.argmax(res)
    if np.argmax(y_train[i])==predicted:
        cnt += 1
    else:
        feature = np.zeros((5,))
        for j in range(5):
            feature[j] = np.argmax(X_train[i,j*10:(j+1)*10])
            if feature[j] != np.argmax(y_train[i]):
                w[j] -= 0.03
                if w[j] < 0:
                    w[j] = 0
        total = np.sum(w)
        for j in range(5):
            w[j] /= total
    ac = eval_predictions(w) 
    if i % 10 == 0:
        print("%d prediction:" % i)
        print 'weights: ', w, " accuracy: ", ac
    acc.append(ac)
# Out:
# 0 prediction:
# weights:  [ 0.2  0.1  0.3  0.1  0.4]  accuracy:  0.9055
# 10 prediction:
# weights:  [ 0.2  0.1  0.3  0.1  0.4]  accuracy:  0.9055
# 20 prediction:
# weights:  [ 0.16925837  0.04964115  0.32296651  0.04964115  0.40849282]  accuracy:  0.9105
# 30 prediction:
# weights:  [ 0.16383338  0.02310723  0.34466648  0.02310723  0.44528567]  accuracy:  0.912
# 40 prediction:
# weights:  [ 0.16383338  0.02310723  0.34466648  0.02310723  0.44528567]  accuracy:  0.912
# 50 prediction:
# weights:  [ 0.16482788  0.          0.35562525  0.          0.47954687]  accuracy:  0.9135
# 60 prediction:
# weights:  [ 0.14343391  0.          0.37832474  0.          0.47824135]  accuracy:  0.9145
# 70 prediction:
# weights:  [ 0.12465265  0.          0.38277444  0.          0.49257291]  accuracy:  0.9145
# 80 prediction:
# weights:  [ 0.12465265  0.          0.38277444  0.          0.49257291]  accuracy:  0.9145
# 90 prediction:
# weights:  [ 0.1040139   0.          0.38766422  0.          0.50832188]  accuracy:  0.914
# 100 prediction:
# weights:  [ 0.07873819  0.          0.41240874  0.          0.50885306]  accuracy:  0.914
# 110 prediction:
# weights:  [ 0.07873819  0.          0.41240874  0.          0.50885306]  accuracy:  0.914
# 120 prediction:
# weights:  [ 0.08635468  0.          0.42038686  0.          0.49325846]  accuracy:  0.915
# 130 prediction:
# weights:  [ 0.06192822  0.          0.42899655  0.          0.50907523]  accuracy:  0.915
# 140 prediction:
# weights:  [ 0.06791864  0.          0.43857924  0.          0.49350212]  accuracy:  0.9155
# 150 prediction:
# weights:  [ 0.04166884  0.          0.44898818  0.          0.50934299]  accuracy:  0.9145
# 160 prediction:
# weights:  [ 0.0128229   0.          0.46042657  0.          0.52675053]  accuracy:  0.914
# 170 prediction:
# weights:  [ 0.          0.          0.44407121  0.          0.55592879]  accuracy:  0.9135
# 180 prediction:
# weights:  [ 0.          0.          0.43266329  0.          0.56733671]  accuracy:  0.913
# 190 prediction:
# weights:  [ 0.          0.          0.43266329  0.          0.56733671]  accuracy:  0.913

# %%
json.dump(acc, open('cifar10_ensemble_acc.json', 'w'))

# %% [markdown]
# **online updating plots**

# %%
fig, ax = plt.subplots()
ax.plot(range(len(acc)), acc, label='ensemble')
ax.plot(range(len(acc)), np.ones((len(acc),))*original_acc[4], '--',label='best-single-model')
plt.xlabel('iteration')
plt.ylabel('accuracy')
ax.set_ylim([0.9,0.92])
ax.legend(loc=4)
plt.savefig('cifar10-weight-averging.pdf')

# %% [markdown]
# **EXP3**

# %%
w = np.array([1,2,3])
w=w/float(np.sum(w))
w
# Out:
# array([ 0.16666667,  0.33333333,  0.5       ])

# %%
def exp3(T=2000, eta=0.01):
    w = np.ones(5)
    #w = np.array([1,1,3,1,5])
    test_acc = []
    pt = w/float(np.sum(w))
    perm = np.random.permutation(np.arange(X_train.shape[0]))
    for i in range(T):
        pt = w/float(np.sum(w))
        ind = np.random.choice(np.arange(5), p=pt) ### choose one model to update
        pred = np.argmax(X_train[perm[i],ind*10:(ind+1)*10])
        loss = int(pred!=np.argmax(y_train[perm[i]]))
        w[ind] *= np.exp(-1*eta*(loss/pt[ind]))
        ac = original_acc[ind]
        test_acc.append(ac)
        if (i+1) % 1000 == 0:
            print(i, 'prediction: pt is ', pt, 'sum of pt is ', np.sum(pt) ,' acc = ', ac)
    return w, test_acc

# %%
w, acc = exp3(T=2000, eta=0.1)
# Out:
# (999, 'prediction: pt is ', array([ 0.19807507,  0.00063866,  0.39477472,  0.00067512,  0.40583643]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  1
-01]), 'sum of pt is ', 0.99999999999999989, ' acc = ', 0.9085)
# (999, 'prediction: pt is ', array([  4.69363939e-02,   2.80598509e-02,   1.07379784e-01,
#          1.29148092e-14,   8.17623971e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  1.96418907e-03,   1.56157378e-02,   1.22670809e-01,
#          1.96681596e-09,   8.59749263e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (999, 'prediction: pt is ', array([  6.78327140e-09,   1.84767954e-07,   3.11393126e-02,
#          1.00943271e-03,   9.67851063e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  5.15091462e-04,   1.40304567e-02,   4.12736095e-02,
#          8.03892118e-27,   9.44180842e-01]), 'sum of pt is ', 0.99999999999999989, ' acc = ', 0.9085)
# (999, 'prediction: pt is ', array([  2.45592117e-01,   2.02450676e-07,   3.89550056e-02,
#          9.08101904e-04,   7.14544573e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  3.25470917e-02,   2.49879296e-02,   1.78698865e-02,
#          2.29799124e-12,   9.24595092e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (999, 'prediction: pt is ', array([  1.40384536e-04,   9.04420612e-02,   3.64597912e-01,
#          8.42469412e-03,   5.36394948e-01]), 'sum of pt is ', 0.99999999999999989, ' acc = ', 0.54)
# (1999, 'prediction: pt is ', array([  4.29079308e-03,   4.14183671e-06,   1.97706255e-02,
#          2.01524861e-03,   9.73919191e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (999, 'prediction: pt is ', array([  4.27459180e-03,   2.12534638e-04,   2.37153839e-01,
#          2.08547176e-03,   7.56273563e-01]), 'sum of pt is ', 1.0000000000000002, ' acc = ', 0.832)
# (1999, 'prediction: pt is ', array([  4.15042201e-04,   4.83069810e-16,   3.94185697e-02,
#          5.02419304e-03,   9.55142195e-01]), 'sum of pt is ', 0.99999999999999989, ' acc = ', 0.9085)
# (999, 'prediction: pt is ', array([  1.23233482e-13,   1.78964960e-03,   6.09197040e-02,
#          3.75167604e-07,   9.37290271e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  1.81806754e-08,   1.34174039e-05,   2.58252914e-03,
#          1.57233701e-09,   9.97404034e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (999, 'prediction: pt is ', array([  4.48553418e-03,   1.44575990e-02,   3.92282615e-02,
#          2.92600501e-11,   9.41828605e-01]), 'sum of pt is ', 0.99999999999999989, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  3.97636296e-25,   2.05086077e-02,   4.26186455e-04,
#          2.28220938e-06,   9.79062924e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (999, 'prediction: pt is ', array([  2.14634865e-08,   2.96422718e-04,   4.88942072e-02,
#          1.64164848e-05,   9.50792932e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  9.59666487e-04,   2.21503085e-30,   6.75831217e-02,
#          7.72425072e-05,   9.31379969e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (999, 'prediction: pt is ', array([  1.47972412e-02,   2.91703749e-04,   2.84017573e-01,
#          1.06630913e-07,   7.00893376e-01]), 'sum of pt is ', 0.99999999999999989, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  2.42981455e-05,   1.43463558e-08,   9.16651015e-04,
#          2.34085812e-35,   9.99059036e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (999, 'prediction: pt is ', array([  1.30120709e-11,   3.63961832e-30,   1.07719081e-01,
#          3.98802484e-03,   8.88292894e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  8.49164089e-07,   2.37520469e-25,   7.68821610e-07,
#          1.52349823e-04,   9.99846032e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# finish!

# %%
fig, ax = plt.subplots()
ax.plot(range(len(avg_ac)), avg_ac, label='exp3')
#ax.plot(range(len(avg_ac)), np.ones((len(avg_ac),))*original_acc[4], '--',label='best-single-model')
for i in range(5):
    ax.plot(range(len(avg_ac)), np.ones((len(avg_ac),))*original_acc[i], '--',label='model'+str(i+1))
plt.xlabel('queries')
plt.ylabel('accuracy')
ax.set_ylim([0.5,1])
ax.legend(loc=4)
plt.savefig('cifar10-exp3.pdf')

# %%
json.dump(avg_ac.tolist(), open('cifar-exp3-acc.json', 'w'))

# %%
def exp3_drift(T=2000, eta=0.01):
    w = np.ones(5)
    test_acc = []
    pt = w/float(np.sum(w))
    perm = np.random.permutation(np.arange(X_train.shape[0]))
    for i in range(T):
        pt = w/float(np.sum(w))
        ind = np.random.choice(np.arange(5), p=pt) ### choose one model to update
        if ind == 4 and i>= 1000:
            pred = 0
        else:
            pred = np.argmax(X_train[perm[i],ind*10:(ind+1)*10])
        loss = int(pred!=np.argmax(y_train[perm[i]]))
        w[ind] *= np.exp(-1*eta*(loss/pt[ind]))
        ac = original_acc[ind]
        test_acc.append(ac)
        if (i+1) % 1000 == 0:
            print(i, 'prediction: pt is ', pt, 'sum of pt is ', np.sum(pt) ,' acc = ', ac)
    return w, test_acc

# %%
avg_drift = np.zeros(3000)
for i in range(100):
    w, test_ac = exp3_drift(T=3000,eta=0.1)
    avg_drift += np.array(test_ac)
avg_drift/=100.0
print('finish!')
# Out:
# (999, 'prediction: pt is ', array([  6.67211945e-03,   2.00276935e-07,   5.17231083e-02,
#          7.47087789e-04,   9.40857484e-01]), 'sum of pt is ', 1.0000000000000002, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  4.04034351e-01,   1.87615287e-02,   5.71774279e-01,
#          5.42984158e-03,   1.59399343e-10]), 'sum of pt is ', 1.0, ' acc = ', 0.832)
# (2999, 'prediction: pt is ', array([  1.03688883e-04,   1.64937311e-06,   9.59024173e-01,
#          3.49716146e-04,   4.05207727e-02]), 'sum of pt is ', 0.99999999999999989, ' acc = ', 0.832)
# (999, 'prediction: pt is ', array([  4.46683396e-03,   2.06537951e-09,   4.11235159e-02,
#          9.82954884e-06,   9.54399819e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  9.55859753e-02,   7.29085759e-15,   8.99763527e-01,
#          5.46734723e-04,   4.10376268e-03]), 'sum of pt is ', 1.0, ' acc = ', 0.832)
# (2999, 'prediction: pt is ', array([  2.24451386e-01,   7.01885785e-07,   7.39658795e-01,
#          2.57714334e-03,   3.33119741e-02]), 'sum of pt is ', 1.0, ' acc = ', 0.832)
# (999, 'prediction: pt is ', array([  4.18266690e-05,   2.39211250e-04,   6.76243346e-02,
#          2.24307793e-26,   9.32094627e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  8.36802617e-02,   7.23755523e-21,   9.16319738e-01,
#          2.54808468e-17,   3.45734070e-10]), 'sum of pt is ', 0.99999999999999989, ' acc = ', 0.832)
# (2999, 'prediction: pt is ', array([  3.74364772e-03,   3.23860761e-13,   9.80785699e-01,
#          1.14019806e-09,   1.54706521e-02]), 'sum of pt is ', 1.0, ' acc = ', 0.832)
# (999, 'prediction: pt is ', array([  1.39561132e-04,   8.26393557e-04,   1.73418210e-02,
#          1.72386923e-04,   9.81519837e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  2.61340131e-02,   2.63356669e-02,   9.37434770e-01,
#          1.00955496e-02,   4.07241676e-20]), 'sum of pt is ', 1.0, ' acc = ', 0.832)
# (2999, 'prediction: pt is ', array([  2.04834674e-03,   1.89692537e-01,   8.08243079e-01,
#          1.60376764e-05,   2.04526228e-11]), 'sum of pt is ', 1.0, ' acc = ', 0.832)
# (999, 'prediction: pt is ', array([  1.84259945e-03,   1.25914123e-12,   1.84552458e-02,
#          3.47767467e-07,   9.79701807e-01]), 'sum of pt is ', 0.99999999999999989, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  9.66571768e-03,   4.78310237e-03,   9.84737006e-01,
#          8.13939043e-04,   2.35173181e-07]), 'sum of pt is ', 0.99999999999999978, ' acc = ', 0.832)
# (2999, 'prediction: pt is ', array([ 0.01355827,  0.30362515,  0.6723986 ,  0.00140166,  0.00901632]), 'sum of pt is ', 1.0, ' acc = ', 0.654)
# (999, 'prediction: pt is ', array([  1.21053881e-74,   8.38938300e-10,   1.21543396e-02,
#          9.87089250e-07,   9.87844672e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  3.77931618e-65,   1.74218397e-45,   9.99624394e-01,
#          3.75606400e-04,   0.00000000e+00]), 'sum of pt is ', 0.99999999999999989, ' acc = ', 0.832)
# (2999, 'prediction: pt is ', array([  1.36638582e-56,   6.29874655e-37,   9.99998773e-01,
#          1.22720913e-06,   0.00000000e+00]), 'sum of pt is ', 1.0000000000000002, ' acc = ', 0.832)
# (999, 'prediction: pt is ', array([  2.01853986e-06,   8.17245739e-42,   5.70454718e-02,
#          4.14681082e-05,   9.42911042e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  1.13214690e-06,   6.07356161e-33,   9.88263950e-01,
#          2.02455394e-03,   9.71036434e-03]), 'sum of pt is ', 1.0, ' acc = ', 0.832)
# (2999, 'prediction: pt is ', array([  3.21796385e-02,   6.90597629e-25,   9.61827013e-01,
#          1.64402428e-11,   5.99334805e-03]), 'sum of pt is ', 1.0000000000000002, ' acc = ', 0.832)
# (999, 'prediction: pt is ', array([  5.60245978e-09,   1.01140103e-02,   2.34955957e-01,
#          6.18410227e-04,   7.54311617e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  1.97749839e-010,   7.22744792e-005,   9.99924038e-001,
#          1.61853941e-160,   3.68725988e-006]), 'sum of pt is ', 1.0, ' acc = ', 0.832)
# (2999, 'prediction: pt is ', array([  1.41762010e-002,   8.15534791e-002,   9.04269248e-001,
#          1.16029121e-152,   1.07180316e-006]), 'sum of pt is ', 1.0000000000000002, ' acc = ', 0.832)
# (999, 'prediction: pt is ', array([ 0
), 'sum of pt is ', 1.0, ' acc = ', 0.832)
# (999, 'prediction: pt is ', array([  1.96362874e-03,   8.89416810e-12,   8.53092085e-03,
#          3.50961883e-04,   9.89154489e-01]), 'sum of pt is ', 0.99999999999999989, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  3.72249696e-03,   1.33247160e-07,   9.64919137e-01,
#          3.13582004e-02,   3.25110357e-08]), 'sum of pt is ', 1.0, ' acc = ', 0.832)
# (2999, 'prediction: pt is ', array([  2.36629773e-07,   1.10141371e-01,   8.89824903e-01,
#          4.14412555e-09,   3.34853390e-05]), 'sum of pt is ', 1.0, ' acc = ', 0.832)
# (999, 'prediction: pt is ', array([  5.66790145e-12,   3.02385002e-06,   1.24925388e-08,
#          6.81935876e-08,   9.99996895e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  6.27735703e-03,   1.02761416e-02,   9.65768273e-01,
#          1.76782284e-02,   9.96896789e-77]), 'sum of pt is ', 0.99999999999999989, ' acc = ', 0.832)
# (2999, 'prediction: pt is ', array([  3.20908571e-05,   5.43046282e-03,   9.94537444e-01,
#          1.92052080e-09,   2.33062448e-68]), 'sum of pt is ', 1.0, ' acc = ', 0.832)
# (999, 'prediction: pt is ', array([  1.76512488e-02,   7.33670669e-03,   3.72303352e-03,
#          3.85021295e-25,   9.71289011e-01]), 'sum of pt is ', 1.0, ' acc = ', 0.9085)
# (1999, 'prediction: pt is ', array([  6.54774223e-02,   1.54278700e-02,   9.19093516e-01,
#          7.57071643e-16,   1.19125489e-06]), 'sum of pt is ', 1.0, ' acc = ', 0.832)
# (2999, 'prediction: pt is ', array([  3.73424299e-01,   1.37941719e-02,   6.12780754e-01,
#          3.53937913e-07,   4.20752773e-07]), 'sum of pt is ', 1.0, ' acc = ', 0.7575)
# finish!

# %%
fig, ax = plt.subplots()
ax.plot(range(len(avg_drift)), avg_drift, label='exp3-drift')
for i in range(5):
    ax.plot(range(len(avg_drift)), np.ones((len(avg_drift),))*original_acc[i], '--',label='model'+str(i+1))
plt.axvline(x=1000,color='black',linestyle='--')
ax.annotate('failure in model5', xy=(1001, 0.9), xytext=(1300, 0.92),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
plt.xlabel('queries')
plt.ylabel('accuracy')
ax.set_ylim([0.5,1])
ax.legend(loc=4)
plt.savefig('cifar10-exp3-drift.pdf')

# %%
json.dump(avg_drift.tolist(), open('cifar-exp3-drift.json', 'w'))

# %%
"""
def subtract(T=2000, eta=0.01):
    #pt = np.ones(5)/5 ### initialial weight
    pt = np.array([0.1,0.1,0.2,0.1,0.5])
    test_acc = []
    perm = np.random.permutation(np.arange(X_train.shape[0]))
    for i in range(T):
        ind = np.random.choice(np.arange(5), p=pt) ### choose one model to update
        pred = np.argmax(X_train[perm[i],ind*10:(ind+1)*10])
        loss = int(pred!=np.argmax(y_train[i]))
        #w[ind] *= np.exp(-1*eta*loss/pt[ind])
        pt[ind] -= eta
        if pt[ind]<0:
            pt[ind] = 0
        pt = pt/(np.sum(pt))
        ac = original_acc[ind]
        test_acc.append(ac)
        if (i+1) % 10 == 0:
            print(i, 'prediction: pt is ', pt,  'acc = ', ac)
    return pt, test_acc   
"""

# %% [markdown]
# **confidence prediction**

# %%
w_best = np.array([0.06791864,0,0.43857924,0.,0.49350212])

# %%
def confidence_label(x, num=3):
    '''x is a (50,) feature'''
    pred = []
    for i in range(5):
        pred.append(np.argmax(x[i*10:(i+1)*10]))
    if len(set(pred)) <= (6-num):
        return 1
    else:
        return 0

# %%
def ensemble_confidence_evaluation(num=3):
    n,d = X_test.shape
    total_c = 0
    total_u = 0
    correct_c = 0
    correct_u = 0
    for i in range(n):
        label = confidence_label(X_test[i],num)
        res = np.zeros((10,))
        for j in range(5):
            res += w_best[j]*X_test[i, j*10:(j+1)*10]
        pred = np.argmax(res)
        if label:
            total_c += 1
            if pred == np.argmax(y_test[i]):
                correct_c += 1
        else:
            total_u += 1
            if pred == np.argmax(y_test[i]):
                correct_u += 1
    print 'correct_c = ', correct_c, ' total_c = ', total_c, ' acc = ', float(correct_c)/total_c
    print 'correct_u = ', correct_u, ' total_u = ', total_u, ' acc = ', float(correct_u)/total_u

# %%
ensemble_confidence_evaluation(3)
# Out:
# correct_c =  1777  total_c =  1927  acc =  0.922158796056
# correct_u =  54  total_u =  73  acc =  0.739726027397

# %%
ensemble_confidence_evaluation(4)
# Out:
# correct_c =  1509  total_c =  1607  acc =  0.939016801493
# correct_u =  322  total_u =  393  acc =  0.819338422392

# %%
ensemble_confidence_evaluation(5)
# Out:
# correct_c =  791  total_c =  810  acc =  0.976543209877
# correct_u =  1040  total_u =  1190  acc =  0.873949579832

# %%
ensemble_confidence_evaluation(2)
# Out:
# correct_c =  1829  total_c =  1993  acc =  0.917711991972
# correct_u =  2  total_u =  7  acc =  0.285714285714

# %%
fig, ax = plt.subplots()

four_agree_c = (0.9390, 0.8035)  ## the second is the proportion
four_agree_u = (0.8193, 0.1965)

five_agree_c = (0.9765, 0.405)
five_agree_u = (0.8740, 0.595)

bar_width = 0.3
opacity = 0.4

thin_bar = 0.08
original_acc = [0.7575, 0.654, 0.832, 0.54, 0.9085]

for i in range(len(original_acc)):
    if i == 0:
        rects0 = plt.bar(thin_bar*(i+1), original_acc[i], thin_bar, alpha=opacity, color='y', label='single model')
    else:
        plt.bar(thin_bar*(i+1), original_acc[i], thin_bar, alpha=opacity, color='y')

    
rects1 = plt.bar(0.5+bar_width, 0.9155, bar_width, alpha=opacity, color='g', label='ensemble')
rects2 = plt.bar(1.2+bar_width, four_agree_c[0], four_agree_c[1]*bar_width,  alpha=opacity, color='b', label='confident')
rects3 = plt.bar(1.15+bar_width*2, four_agree_u[0], four_agree_u[1]*bar_width,  alpha=opacity, color='r', label='unsure')
plt.bar(1.95+bar_width, five_agree_c[0], five_agree_c[1]*bar_width,  alpha=opacity, color='b')
plt.bar(2.07+bar_width, five_agree_u[0], five_agree_u[1]*bar_width,  alpha=opacity, color='r')


plt.ylabel('Accuracy')
ax.set_ylim([0.5,1.16])

first_legend = plt.legend(handles=[rects0,rects1], loc=2)
axx = plt.gca().add_artist(first_legend)
second_legend = plt.legend(handles=[rects2,rects3], loc=1)


ind = np.array([0.3,1,1.7,2.4])
plt.xticks(ind, ('single model', 'ensemble', '4-agree', '5-agree'))

cnt = 0
for p in ax.patches:
    if cnt >= 4:
        ax.annotate(str(float(p.get_height())), (p.get_x() * 1.01, p.get_height() * 1.01))
    cnt += 1
plt.savefig('ensemble_confidence_plot.pdf')
